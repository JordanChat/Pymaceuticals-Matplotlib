# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"


# Read the mouse data and the study results
mouse_metadata_df = pd.read_csv(mouse_metadata_path)
study_results_df = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata_df,study_results_df, on='Mouse ID', how='left')
# Display the data table for preview
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Check the number of mice.
total_mice1 = combined_df["Mouse ID"].count()
total_mice1
# Out:
# 1893

# %%
# Find any duplicate rows with the same Mouse ID's and Timepoints. 
combined_df2 = pd.DataFrame(combined_df)
combined_df2

#dropping duplicate rows
main_df = combined_df2.drop_duplicates(subset=['Mouse ID','Timepoint'])
main_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Recheck the number of mice
total_mice2 = main_df["Mouse ID"].count()
total_mice2
# Out:
# 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, 
# standard deviation, and SEM of the tumor volume for each regimen.
summary_statistics = pd.DataFrame(main_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': ['mean', 'median', 'var', 'std', 'sem']}))
summary_statistics
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %%
#putting every column into a count, i need Mouse ID count for number of experiments
summary_statistics2 = pd.DataFrame(main_df.groupby('Drug Regimen').count())
summary_statistics2.head()
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# Ketapril                     188               188
# Naftisol                     186               186

# %%
#seperating the Mouse ID amounts so I can use it to chart my data
experiment_list = pd.DataFrame(summary_statistics2.loc[:, ["Mouse ID"]])
experiment_list

# experiment_df = pd.merge(experiment_list, summary_statistics, on='Drug Regimen')
# experiment_df
# Out:
#               Mouse ID
# Drug Regimen
# Capomulin          230
# Ceftamin           178
# Infubinol          178
# Ketapril           188
# Naftisol           186
# Placebo            181
# Propriva           156
# Ramicane           228
# Stelasyn           181
# Zoniferol          182

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of datapoints for each drug regimen using pandas.
# There should be a single bar per regimen


experiment_list.plot(kind="bar", color="#CA6F33", title= "Datapoints For Each Drug Regimen")
plt.legend()
plt.xlabel('Drug Regimen')
plt.ylabel('Experiments')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Generate identical bar plot using pyplot instead of pandas.
x_axis = np.arange(len(experiment_list))
plt.bar(x_axis, experiment_list["Mouse ID"], color="g", alpha=0.5)
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(experiment_list.index), rotation="vertical")
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(experiment_list["Mouse ID"])+10)
plt.title("Datapoints For Each Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Experiments")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
#first finding the counts of male and female
explode = (0.1,0)
colors = ["cornflowerblue", "plum"]
mice_gender_dist = main_df["Sex"].value_counts()
plt.figure()
mice_gender_dist.plot(kind="pie", explode=explode, colors=colors, autopct= '%1.1f%%', shadow=True)
plt.axis("equal")
plt.title("Female vs Male Distribution")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Generate identical pie plot using pyplot
colors = ["indianred", "olive"]
labels = ["Male", "Female"]
explode = (0.1, 0)
plt.figure()
plt.pie(mice_gender_dist.values, labels=labels, explode=explode, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")
plt.title("Female vs Male Distribution")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# main_df.groupby("Drug Regimen")
#use | "or" opertator
regimen_df = main_df[(main_df["Drug Regimen"] == "Capomulin") |
                    (main_df["Drug Regimen"] == "Ramicane") |
                    (main_df["Drug Regimen"] == "Infubinol") |
                    (main_df["Drug Regimen"] == "Ceftamin")]

final_tumor = regimen_df.groupby(["Mouse ID", "Drug Regimen"]).agg(\
    final_tumor = ('Tumor Volume (mm3)',lambda x: x.iloc[-1])).round(3)

final_tumor


# regimen_df = regimen_df[["Mouse ID", "Drug Regimen", "Tumor Volume (mm3)"]]
# regimen_df


#I grouped the Mouse ID and Drug Regimen together, and totaled the sum of the Tumor Volume for each
# grouped_regimen = regimen_df.groupby(["Mouse ID", "Drug Regimen"]).agg({'Tumor Volume (mm3)': ['sum']})
# grouped_regimen

# HINT: Not all mice lived until timepoint 45
# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
#                        final_tumor
# Mouse ID Drug Regimen
# a203     Infubinol          67.973
# a251     Infubinol          65.526
# a275     Ceftamin           62.999
# a411     Ramicane           38.408
# a444     Ramicane           43.048
# ...                            ...
# y769     Ceftamin           68.595
# y793     Capomulin          31.896
# y865     Ceftamin           64.730
# z578     Ramicane           30.639
# z581     Infubinol          62.754
#
# [100 rows x 1 columns]

# %% [markdown]
# Calculate the quartiles and IQR and quantitatively determine if there are any potential outliers across all four treatment regimens.

# %%
# Calculate quartiles, IQR, and identify potential outliers for each regimen.
quartiles = final_tumor.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The Lower quartile is: {lowerq}")
print(f"The upper quartile is: {upperq}")
print(f"The interquartile range is: {iqr}")
print(f"The median is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")



#Trying to calculate my quartiles... dont know why i get an error that says 0.25



# One method to do this is the following, but you can use whatever method works for you.

##############################################################################
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0.25
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-bb30c2e71c3d> in <module>
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# There should be a single chart with four box plots inside it.
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumor Volume of Each Mouse")
ax1.set_ylabel("Tumor Vol (mm3)")
ax1.boxplot(final_tumor)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse 
# treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight 
# for all mice in the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

# %% [markdown]
# # Observations and Insights

# %% [markdown]
# - The first major observation we notice in the data are the lowest drug regimens by mean. This is great indictation of which regimen's are worth taking a look at.
# - The second observation we can take from the data is how the placebo regimen still has around the same data as the actual drug regimen's given. This could be something that a pharmaceutical company would want to take a look at.
# - The final observation we can take from the data is how the drug regimen's are just about evenly distributed between male and female mice.
